# %% [markdown]
# ## Variables

# %%
a = "Here a is a Variable"

# %% [markdown]
# ## Output Statement

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Input Statement

# %%
b = input("Enter here;")

# %%
b
# Out:
# '8'

# %% [markdown]
# ## Data Types

# %%
a="Hello"
b= 2
c = 3.4
d = True
f = [1,2,3]
g = (1,2,3)
i = {1:'a', 2:'b'}
j = 2+9j

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(f))
print(type(g))
print(type(i))
print(type(j))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'complex'>
